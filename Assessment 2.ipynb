# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\User\\Desktop\\DataSkillCraft.csv')
print(data)
# Out:
#       Unnamed: 0  GameID  LeagueIndex  Age  HoursPerWeek  TotalHours  \
# 0              0      52            5   27            10        3000
# 1              1      55            5   23            10        5000
# 2              2      56            4   30            10         200
# 3              3      57            3   19            20         400
# 4              4      58            3   32            10         500
# ...          ...     ...          ...  ...           ...         ...
# 3333        3333    9261            4   20             8         400
# 3334        3334    9264            5   16            56        1500
# 3335        3335    9265            4   21             8         100
# 3336        3336    9270            3   20            28         400
# 3337        3337    9271            4   22             6         400
#
#            APM  SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  ...  \
# ...

# %%
# drop nonsense data
df = data.drop(data[data.HoursPerWeek >= 168].index)
df.drop(columns=['GameID'])
# Out:
#       Unnamed: 0  LeagueIndex  Age  HoursPerWeek  TotalHours       APM  \
# 0              0            5   27            10        3000  143.7180
# 1              1            5   23            10        5000  129.2322
# 2              2            4   30            10         200   69.9612
# 3              3            3   19            20         400  107.6016
# 4              4            3   32            10         500  122.8908
# ...          ...          ...  ...           ...         ...       ...
# 3333        3333            4   20             8         400  158.1390
# 3334        3334            5   16            56        1500  186.1320
# 3335        3335            4   21             8         100  121.6992
# 3336        3336            3   20            28         400  134.2848
# 3337        3337            4   22             6         400   88.8246
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# ...

# %%
import matplotlib as plt

# %%
import seaborn as sns

corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
               square=True)

# %%
datos = df.drop(columns = ['Unnamed: 0', 'TotalHours', 'MinimapRightClicks', 'ActionsInPAC', 'TotalMapExplored', 'UniqueUnitsMade', 'ComplexUnitsMade', 'ComplexAbilitiesUsed'])

# %%
df.to_csv("SkillCraft(11).csv")

# %%
import matplotlib.pyplot as plt 
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
datos.to_csv("C:\\Users\\User\\Desktop\\Database.csv")

# %%
datos.drop(['LeagueIndex'],1).hist()
plt.show()

# %%
sb.pairplot(datos.dropna(), hue='LeagueIndex',size=4,vars=["Age","APM","SelectByHotkeys",'AssignToHotkeys','UniqueHotkeys','NumberOfPACs','GapBetweenPACs','ActionLatency','WorkersMade'],kind='scatter')
